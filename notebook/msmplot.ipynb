# %%
using BSON: @load @save
using MDToolbox
# Out:
# ┌ Info: Precompiling MDToolbox [7965e2f0-a35b-11e8-0207-19c030dd2def]
# └ @ Base loading.jl:1278

# %%
@load "data/t1r/t1r.bson" T pi_i centroid

# %%
# pi_iを持っていなければ与えなくても大丈夫(Tからpi_iを内部で計算する)
msmplot(T, pi_i=pi_i, x=centroid[:, 1], y=centroid[:,2], filename="msmplot.png", dpi=150)
